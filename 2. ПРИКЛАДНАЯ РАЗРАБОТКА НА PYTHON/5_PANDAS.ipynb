# %% [markdown]
# В заданиях этого урока нам предстоит проанализировать данные об американских закусочных. Мы поищем, где можно купить тако в Калифорнии, в какие месяцы чаще всего открывали рестораны.
#
# [Данные](https://disk.yandex.ru/d/rQHqv7DLTz-ybw)

# %%
import pandas as pd
df = pd.read_csv('data_5.csv')#, index ='id')

# %%
df.head()
# Out:
#                      id                   address  \
# 0  AVwc__cikufWRAb51QjV         610 Commercial St
# 1  AVwc__cikufWRAb51QjV         610 Commercial St
# 2  AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3  AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4  AVwc__WtByjofQCxkdkR             8495 W 3rd St
#
#                                           categories         city  \
# 0  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 1  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 2       Golf Course, American Restaurant, and Resort    Patterson
# 3                               Fast Food Restaurant     Longmont
# 4  Mexican Restaurant Mid-City West,Mexican Resta...  Los Angeles
#
#                       cuisines             dateAdded           dateUpdated  \
# 0  Restaurant Delivery Service  2016-03-02T11:49:34Z  2017-02-01T18:04:44Z
# 1  Restaurant Delivery Service  2016-03-02T11:49:34Z  2017-02-01T18:04:44Z
# ...

# %%
df.columns
# Out:
# Index(['id', 'address', 'categories', 'city', 'cuisines', 'dateAdded',
#        'dateUpdated', 'latitude', 'longitude', 'menus.category',
#        'menus.currency', 'menus.dateSeen', 'menus.description', 'menus.name',
#        'name', 'province'],
#       dtype='object')

# %%
data = df.copy()

# %%
data.dtypes

# %%
data.describe()

# %%
data.dropna().shape

# %%
result = data[
  ((data['city'] == 'New York') | (data['name'] == 'Taco Bell')) &
  (~(data['menus.name'].isin(['Volcano Taco', 'Fresco Soft Taco'])))
]

# %%
data[((data['city']=='New York')|(data['name']=='Taco Bell'))&(~(data['menus.name'].isin(['Volcano Taco', 'Fresco Soft Taco'])))].head()
# Out:
#                        id          address  \
# 131  AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 132  AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 133  AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 135  AVwc_9yCByjofQCxkdRX  322 S. Broadway
# 136  AVwc_9yCByjofQCxkdRX  322 S. Broadway
#
#                                             categories   city cuisines  \
# 131  Fast Food,Restaurants,Mexican,Breakfast,Vegeta...  Salem  Mexican
# 132  Fast Food,Restaurants,Mexican,Breakfast,Vegeta...  Salem  Mexican
# 133  Fast Food,Restaurants,Mexican,Breakfast,Vegeta...  Salem  Mexican
# 135  Fast Food,Restaurants,Mexican,Breakfast,Vegeta...  Salem  Mexican
# 136  Fast Food,Restaurants,Mexican,Breakfast,Vegeta...  Salem  Mexican
#
#                 dateAdded           dateUpdated   latitude  longitude  \
# 131  2016-03-28T06:01:51Z  2017-06-27T10:01:48Z  42.755023  -71.20944
# 132  2016-03-28T06:01:51Z  2017-06-27T10:01:48Z  42.755023  -71.20944
# ...

# %%
data[~(data['menus.currency'].isna())].head()
# Out:
#                       id           address  \
# 15  AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 16  AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 17  AVwc_1y6kufWRAb51O6w   906 Park Ave SW
# 18  AVwc_2OQ_7pvs4fz1L5H  100 W Higgins Rd
# 19  AVwc_2OQ_7pvs4fz1L5H  100 W Higgins Rd
#
#                               categories         city  \
# 15  Coffee Shop,Restaurants,Coffeehouses  Albuquerque
# 16  Coffee Shop,Restaurants,Coffeehouses  Albuquerque
# 17  Coffee Shop,Restaurants,Coffeehouses  Albuquerque
# 18                            Restaurant   Barrington
# 19                            Restaurant   Barrington
#
#                    cuisines             dateAdded           dateUpdated  \
# 15             Coffee Shops  2016-06-05T20:15:56Z  2017-07-06T13:28:29Z
# 16             Coffee Shops  2016-06-05T20:15:56Z  2017-07-06T13:28:29Z
# 17             Coffee Shops  2016-06-05T20:15:56Z  2017-07-06T13:28:29Z
# 18  Mexican, Latin American  2016-07-26T17:39:41Z  2016-08-26T05:25:56Z
# ...

# %%
data[data['city'] == 'California'].index

# %%
data[(data['city'] == 'California') & (data['name'] == 'Taco Bell')].index

# %%
data.groupby('city').agg({'id': 'count'}).sort_values(by='id', ascending=False).head(5)
# Out:
#                  id
# city
# San Diego      1924
# Los Angeles    1603
# Chicago        1186
# San Francisco  1120
# New York       1085

# %%
data['city'].value_counts()

# %%
data[data['name']=='Taco Bell'].groupby('city').agg({'id': 'count'}).sort_values(by='id', ascending=False).head(5)
# Out:
#              city  id
# 51   Indianapolis  84
# 30       Columbus  63
# 21     Charleston  63
# 117         Tampa  62
# 42         Fresno  42

# %%
result = data[data['name'] == 'Taco Bell']['city'].value_counts()[:5]

# %%
result = data[data['name'] == 'Taco Bell'].groupby('city').count()['id'].sort_values(ascending=False)[:5]b

# %%
data[data['name']=='Taco Bell'].groupby('city')['id'].count().sort_values(ascending=False).head(5)
# Out:
# city
# Indianapolis    84
# Columbus        63
# Charleston      63
# Tampa           62
# Fresno          42
# Name: id, dtype: int64

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'])
data['dateUpdated'] = pd.to_datetime(data['dateUpdated'])
data.head(5)
# Out:
#                      id                   address  \
# 0  AVwc__cikufWRAb51QjV         610 Commercial St
# 1  AVwc__cikufWRAb51QjV         610 Commercial St
# 2  AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3  AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4  AVwc__WtByjofQCxkdkR             8495 W 3rd St
#
#                                           categories         city  \
# 0  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 1  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 2       Golf Course, American Restaurant, and Resort    Patterson
# 3                               Fast Food Restaurant     Longmont
# 4  Mexican Restaurant Mid-City West,Mexican Resta...  Los Angeles
#
#                       cuisines                 dateAdded  \
# 0  Restaurant Delivery Service 2016-03-02 11:49:34+00:00
# 1  Restaurant Delivery Service 2016-03-02 11:49:34+00:00
# 2                          NaN 2016-10-14 01:58:25+00:00
# ...

# %%
data['update_delta'] = (data['dateUpdated'] - data['dateAdded']).dt.days
data.head(5)
# Out:
#                      id                   address  \
# 0  AVwc__cikufWRAb51QjV         610 Commercial St
# 1  AVwc__cikufWRAb51QjV         610 Commercial St
# 2  AVwc__dF_7pvs4fz1Ncy      9521 Morton Davis Dr
# 3  AVwc__kCByjofQCxkdm-  10550 W I 25 Frontage Rd
# 4  AVwc__WtByjofQCxkdkR             8495 W 3rd St
#
#                                           categories         city  \
# 0  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 1  Restaurant Delivery Service,Restaurants,Pizza,...     Atchison
# 2       Golf Course, American Restaurant, and Resort    Patterson
# 3                               Fast Food Restaurant     Longmont
# 4  Mexican Restaurant Mid-City West,Mexican Resta...  Los Angeles
#
#                       cuisines                 dateAdded  \
# 0  Restaurant Delivery Service 2016-03-02 11:49:34+00:00
# 1  Restaurant Delivery Service 2016-03-02 11:49:34+00:00
# 2                          NaN 2016-10-14 01:58:25+00:00
# ...

# %%
result = data.groupby(data['city'], as_index=False).agg({'update_delta': 'mean', 'latitude': 'max'})

zep_mean = float(result[result['city']=='Zephyrhills']['update_delta'])

# %%
data['name'][data['dateAdded'].dt.month==10].head(5)
# Out:
# 2     Diablo Grande Golf & Country Club
# 21                         Riff's Joint
# 22                         Riff's Joint
# 23                         Riff's Joint
# 24                         Riff's Joint
# Name: name, dtype: object

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'])
# .dt.month вернет Series месяцев у соответствующих записей - их сравним с 11
data[data['dateAdded'].dt.month == 10]

# %%
data.groupby(data['dateAdded'].dt.month).agg({'id': 'nunique'})
# Out:
#              id
# dateAdded
# 1           308
# 2           257
# 3          4970
# 4          3224
# 5          1141
# 6          1356
# 7           645
# 8           479
# 9           554
# 10         4716
# 11         1550
# 12          239

# %%
result = data.groupby(data['dateAdded'].dt.month).agg({'id': 'nunique'})b

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'])
data['dateUpdated'] = pd.to_datetime(data['dateUpdated'])
data['update_delta'] = (data['dateUpdated'] - data['dateAdded']).dt.days
result = data.groupby(data['city'], as_index=False).agg({'update_delta': 'mean', 'latitude': 'max'})

zep_mean = float(result[result['city']=='Zephyrhills']['update_delta'])

# %%
result
# Out:
#               city  update_delta   latitude
# 0        Abbeville    114.857143  29.982108
# 1         Aberdeen     81.625000  46.975110
# 2          Abilene    206.454545  32.453090
# 3         Abingdon    303.500000  36.712800
# 4         Abington    393.000000  40.124851
# ...            ...           ...        ...
# 3596       Zebulon      0.000000  33.102090
# 3597   Zephyr Cove    105.500000  38.984947
# 3598   Zephyrhills    329.695652  28.271183
# 3599  Zieglerville    621.000000  40.291611
# 3600    Zionsville    151.500000  39.954970
#
# [3601 rows x 3 columns]

# %%
data['update_delta'] = (data['dateUpdated'] - data['dateAdded']).dt.days
result = data.groupby('city', as_index=False).agg({'update_delta': 'mean', 'latitude': 'max'})
# через .loc можно писать в одних [] сразу и условие, и желаемые колонки
# вот так: .loc[условие, колонки]
zep_mean = data.loc[data['city'] == 'Zephyrhills', 'update_delta'].mean()

# %%
data[data['categories'].str.contains('Pizza')]
# Out:
#                          id                     address  \
# 0      AVwc__cikufWRAb51QjV           610 Commercial St
# 1      AVwc__cikufWRAb51QjV           610 Commercial St
# 66     AVwc_59U_7pvs4fz1Md3            3250 Kennedy Cir
# 67     AVwc_59U_7pvs4fz1Md3            3250 Kennedy Cir
# 158    AVwc_AmZkufWRAb51FxA               133 Howard St
# ...                     ...                         ...
# 76256  AVweVOBFByjofQCxxRnN          3000 N Dinuba Blvd
# 76291  AVweVXD4ByjofQCxxS7L            35 N Farview Ave
# 76507  AVweWyOEkufWRAb5CNJU  1516 E Historic Highway 66
# 76669  AVweXxalByjofQCxxnWC        1895 Washington Blvd
# 76709  AVweYFH-ByjofQCxxqHG              620 Water St S
#
#                                               categories        city  \
# 0      Restaurant Delivery Service,Restaurants,Pizza,...    Atchison
# 1      Restaurant Delivery Service,Restaurants,Pizza,...    Atchison
# 66     Pizza,Take Out Restaurants,Caterers,Restaurant...     Dubuque
# ...

# %%
round(data['update_delta'].mean(), 2)
# Out:
# 326.22

# %%
round(data['update_delta'].median(), 2)
# Out:
# 364.0

# %%
df['update_delta'] = (df['dateUpdated'] - df['dateAdded']).dt.days
print(df['update_delta'].mean())
print(df['update_delta'].median())

# %%
data['categories_split'] = data['categories'].str.split(',')

# %%
data['categories_len'] = data['categories'].str.split(',').apply(len)#.value_counts()

# %%
res = data[data['categories_len'] > 20].groupby('province').agg({'longitude': 'min'}).round(3)

# %%
res.to_csv('ml_5_18.csv', sep=';')

# %% [markdown]
# В этом задании нужно отобрать записи, у которых более 20 категорий, далее их нужно сгруппировать по провинциям и подсчитать минимальную longitude в каждой. Округлите значения longitude до 3-х знаков после запятой.
#
# Далее сохраните результирующий датафрейм в файл в формате csv с сепаратором ;. Сам датафрейм должен содержать две колонки: province и longitude

# %%
tmp = data[data['categories'].str.split(',').str.len() > 20].groupby('province')['longitude'].min().round(3)
tmp.to_csv('hw_7.csv', sep=';')
